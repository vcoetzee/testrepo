# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Vinet Coetzee**
# Associate Professor

# %% [markdown]
# *I am interested in data science because it allows me to more fully interpret and communicate the story behind the data*

# %% [markdown]
# ### The following code aims to add 2 and 2 together

# %%
2+2
# Out:
# 4

# %% [markdown]
# ### Some things I've learned in this course
# ___
# 1. How to change the font to **bold** or *italics*
# 2. How to ~~striketrhough~~ a word
# 3. How to insert a [hyperlink](https://www.wikipedia.org/)
# 4. How to make a numbered list, such as this
# - or a bullet list such as this
